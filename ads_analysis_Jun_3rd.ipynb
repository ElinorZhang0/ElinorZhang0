# %% [markdown]
# <a href="https://colab.research.google.com/github/ElinorZhang0/ElinorZhang0/blob/main/ads_analysis_Jun_3rd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from pprint import pprint
from pandas import Series, DataFrame
from pathlib import Path
import glob
from numpy.lib import type_check
import os
import pyarrow.parquet as pq
import matplotlib.pyplot as plt

# %%
from google.colab import drive
# If drive is not already mounted: 
if not Path('/content/drive').exists():
  drive.mount('/content/drive')

# %%
os.chdir("/content/drive/Shareddrives/Modeling Files/CD16 List/San Mateo Voter Data")

# %%
# read table 
SM_new=pd.read_parquet('2022Jun_CD16_20220224_075502.parquet')
pd.options.display.max_columns = None
pd.options.display.max_rows = None
print(SM_new.shape)
#print(SM_new.DistrictID_1.unique())
SM_new.head()
# Out:
# (82158, 114)
#   RegistrationNumber   VoterID VoterTitle  LastName FirstName MiddleName  \
# 0         00  576015  97670797       Mrs     Wetzel     Naomi          L
# 1         00  970732  97647830       Mrs      Louie   Eugenia          A
# 2         00 R005472  76005526       None  Johnston   William     Robert
# 3         00__000000  97490517       None     Shick     Jesse    Calvert
# 4         00_E219182  97308675       None     Munks     Bryan    William
#
#   NameSuffix Gender Ethnicity     ResidenceAddress   ResidenceCity  \
# 0       None   None      None      1941 Oakdell Dr      Menlo Park
# 1       None   None      None       1025 Wallea Dr      Menlo Park
# 2       None      U      None     1161 Tamarind St         Montara
# 3       None   None     WHITE       311 Correas St   Half Moon Bay
# 4       None   None      None  393 Golden Hills Dr  Portola Valley
#
#   ResidenceState  ResidenceZipCode PreDirection    StreetName StreetSuffix  \
# ...

# %%
SM_new['ResidenceCity'].value_counts()
# Out:
# Pacifica          26670
# Menlo Park        17917
# Half Moon Bay      8718
# Woodside           5384
# Portola Valley     5376
# Atherton           4956
# El Granada         4153
# Redwood City       2568
# Montara            2145
# Moss Beach         1981
# La Honda           1126
# Pescadero           763
# San Gregorio        189
# Loma Mar            143
# Princeton            66
# Burlingame            3
# Name: ResidenceCity, dtype: int64

# %%
SM_new['ResidenceZipCode'].value_counts()
# Out:
# 94044    26670
# 94025    17917
# 94019     8733
# 94062     5581
# 94028     5376
# 94027     4956
# 94018     4204
# 94061     2380
# 94037     2147
# 94038     1979
# 94020     1117
# 94060      763
# 94074      189
# 94021      143
# 94010        3
# Name: ResidenceZipCode, dtype: int64

# %%
os.chdir("/content/drive/Shareddrives/Modeling Files/CD16 List/Santa Clara Voter Data")

# %%
SC_new=pd.read_parquet('MVMJ004_Cust_20220216_090728_16thCongDist.parquet')
print(SC_new.shape)
SC_new.head()
# Out:
# (353786, 62)
#    lVoterUniqueID  sAffNumber  szStateVoterID sVoterTitle szNameLast  \
# 0           70633  65BU165715             NaN        None      Jones
# 1         1009844  65CB365500             NaN        None    Nielsen
# 2         2569637  43TA660731             NaN        Miss    Bazzazi
# 3         2900985  65CL640796             NaN        None     Ahmadi
# 4         2185012  65BU971459             NaN        None    Murison
#
#   szNameFirst szNameMiddle sNameSuffix sGender       szSitusAddress  \
# 0     Loretta         Lynn        None    None  1489 Carrington Cir
# 1       Karyn          Lyn        None    None  1493 Carrington Cir
# 2      Marjan         None        None    None  1457 Carrington Cir
# 3     Mahmoud         Reza        None    None  1457 Carrington Cir
# 4      Ashley      Janette        None    None  1473 Carrington Cir
#
#   szSitusCity sSitusState  sSitusZip   sHouseNum sUnitAbbr sUnitNum  \
# ...

# %%
SC_new['sSitusZip'].value_counts()
# Out:
# 95125    31317
# 95124    29148
# 95008    27830
# 95070    23586
# 95118    18183
# 95032    17871
# 94306    16915
# 94040    16682
# 94024    16207
# 95111    15754
# 94043    14977
# 94022    14726
# 95121    12705
# 94303    11645
# 95122    11469
# 94301    11163
# 95128    10340
# 95030     9883
# 94041     7569
# 95130     6540
# 95136     6160
# 95129     5500
# 95126     4090
# 94305     3853
# 95033     2623
# 94304     1765
# 95120     1724
# 95117     1687
# 95112     1448
# 95014      265
# 94028      123
# 95044       26
# 94087        4
# 95135        2
# 94035        2
# 94085        1
# 95031        1
# 94042        1
# 95148        1
# Name: sSitusZip, dtype: int64

# %%
SC_new['szSitusCity'].value_counts()
# Out:
# San Jose           156070
# Palo Alto           41594
# Mountain View       39229
# Campbell            27828
# Los Gatos           27661
# Los Altos           24580
# Saratoga            23586
# Los Altos Hills      6353
# Stanford             3747
# Monte Sereno         2717
# Cupertino             265
# Portola Valley        123
# Redwood Estates        26
# Sunnyvale               5
# Moffett Field           2
# Name: szSitusCity, dtype: int64

# %%
cd /content/drive/MyDrive/Google ads
# Out:
# /content/drive/MyDrive/Google ads

# %%
ls

# %%
Location_report_June_3_overall = pd.read_csv('Location report 6:3.csv')
Location_report_June_3_overall.head()
# Out:
#                                      Location Bid adj. Clicks   Impr.    CTR  \
# 0            95032, California, United States       --      0       0     --
# 1            94062, California, United States       --      0       0     --
# 2    Half Moon Bay, California, United States       --     98  27,206  0.36%
# 3            94028, California, United States       --      0       0     --
# 4  Los Altos Hills, California, United States       --      4   1,493  0.27%
#
#   Currency code Avg. CPC   Cost  Conversions  Cost / conv. Conv. rate
# 0           USD       --   0.00          0.0           0.0      0.00%
# 1           USD       --   0.00          0.0           0.0      0.00%
# 2           USD     0.39  38.62          0.0           0.0      0.00%
# 3           USD       --   0.00          0.0           0.0      0.00%
# 4           USD     0.84   3.35          0.0           0.0      0.00%
